# %%
import pandas as pd
path = '/content/drive/MyDrive/services.csv'

# %%
df = pd.read_csv(path)
df.describe
# Out:
# <bound method NDFrame.describe of     id  location_id  program_id         accepted_payments  \
# 0    1            1         NaN                       NaN
# 1    2            2         NaN                       NaN
# 2    3            3         NaN                       NaN
# 3    4            4         NaN                       NaN
# 4    5            5         NaN                       NaN
# 5    6            6         NaN                       NaN
# 6    7            7         NaN                       NaN
# 7    8            8         NaN                       NaN
# 8    9            9         NaN                       NaN
# 9   10           10         NaN                       NaN
# 10  11           11         NaN                       NaN
# 11  12           12         NaN                       NaN
# 12  13           13         NaN                       NaN
# 13  14           14         NaN                       NaN
# 14  15           15         NaN                       NaN
# ...

# %%
df.head()
# Out:
#    id  location_id  program_id accepted_payments alternate_name  \
# 0   1            1         NaN               NaN            NaN
# 1   2            2         NaN               NaN            NaN
# 2   3            3         NaN               NaN            NaN
# 3   4            4         NaN               NaN            NaN
# 4   5            5         NaN               NaN            NaN
#
#                            application_process  \
# 0                   Walk in or apply by phone.
# 1           Apply by phone for an appointment.
# 2  Phone for information (403-4300 Ext. 4322).
# 3                              Apply by phone.
# 4                       Phone for information.
#
#                                             audience  \
# 0  Older adults age 55 or over, ethnic minorities...
# 1       Residents of San Mateo County age 55 or over
# 2  Older adults age 55 or over who can benefit fr...
# 3  Parents, children, families with problems of c...
# ...

# %%
df.head(2)
# Out:
#    id  location_id  program_id accepted_payments alternate_name  \
# 0   1            1         NaN               NaN            NaN
# 1   2            2         NaN               NaN            NaN
#
#                   application_process  \
# 0          Walk in or apply by phone.
# 1  Apply by phone for an appointment.
#
#                                             audience  \
# 0  Older adults age 55 or over, ethnic minorities...
# 1       Residents of San Mateo County age 55 or over
#
#                                          description  \
# 0  A walk-in center for older adults that provide...
# 1  Provides training and job placement to eligibl...
#
#                                          eligibility email  ...  \
# 0  Age 55 or over for most programs, age 60 or ov...   NaN  ...
# 1  Age 55 or over, county resident and willing an...   NaN  ...
#
#   interpretation_services                                           keywords  \
# ...

# %%
df.tail()
# Out:
#     id  location_id  program_id         accepted_payments  \
# 18  19           19         NaN                       NaN
# 19  20           20         NaN                       NaN
# 20  21           21         NaN                       NaN
# 21  22           22         NaN  Cash, Check, Credit Card
# 22  23           22         NaN                       NaN
#
#            alternate_name                             application_process  \
# 18                    NaN  Call for screening appointment (650-347-3648).
# 19                    NaN                                        Walk in.
# 20                    NaN                 By phone during business hours.
# 21  Fotos para pasaportes               Walk in or apply by phone or mail
# 22                    NaN               Walk in or apply by phone or mail
#
#                                              audience  \
# 18                                                NaN
# 19                                                NaN
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns
# Out:
# Index(['id', 'location_id', 'program_id', 'accepted_payments',
#        'alternate_name', 'application_process', 'audience', 'description',
#        'eligibility', 'email', 'fees', 'funding_sources',
#        'interpretation_services', 'keywords', 'languages', 'name',
#        'required_documents', 'service_areas', 'status', 'wait_time', 'website',
#        'taxonomy_ids'],
#       dtype='object')

# %%
list(df.columns)
# Out:
# ['id',
#  'location_id',
#  'program_id',
#  'accepted_payments',
#  'alternate_name',
#  'application_process',
#  'audience',
#  'description',
#  'eligibility',
#  'email',
#  'fees',
#  'funding_sources',
#  'interpretation_services',
#  'keywords',
#  'languages',
#  'name',
#  'required_documents',
#  'service_areas',
#  'status',
#  'wait_time',
#  'website',
#  'taxonomy_ids']

# %%
df['email']
# Out:
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# 5                       NaN
# 6                       NaN
# 7                       NaN
# 8                       NaN
# 9                       NaN
# 10                      NaN
# 11                      NaN
# 12                      NaN
# 13                      NaN
# 14                      NaN
# 15                      NaN
# 16                      NaN
# 17                      NaN
# 18                      NaN
# 19                      NaN
# 20                      NaN
# 21    passports@example.org
# 22                      NaN
# Name: email, dtype: object

# %%
type(df['email'])
# Out:
# pandas.core.series.Series

# %%
list(df['email'])
# Out:
# [nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'passports@example.org',
#  nan]

# %%
df[['email']]
# Out:
#                     email
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# 5                     NaN
# 6                     NaN
# 7                     NaN
# 8                     NaN
# 9                     NaN
# 10                    NaN
# 11                    NaN
# 12                    NaN
# 13                    NaN
# 14                    NaN
# 15                    NaN
# 16                    NaN
# 17                    NaN
# 18                    NaN
# 19                    NaN
# 20                    NaN
# 21  passports@example.org
# 22                    NaN

# %%
type(df[['email']])
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns
# Out:
# Index(['id', 'location_id', 'program_id', 'accepted_payments',
#        'alternate_name', 'application_process', 'audience', 'description',
#        'eligibility', 'email', 'fees', 'funding_sources',
#        'interpretation_services', 'keywords', 'languages', 'name',
#        'required_documents', 'service_areas', 'status', 'wait_time', 'website',
#        'taxonomy_ids'],
#       dtype='object')

# %%
df[['email','id','status','name']]
# Out:
#                     email  id    status                                  name
# 0                     NaN   1    active       Fair Oaks Adult Activity Center
# 1                     NaN   2    active      Second Career Employment Program
# 2                     NaN   3    active                Senior Peer Counseling
# 3                     NaN   4    active              Family Visitation Center
# 4                     NaN   5    active     Economic Self-Sufficiency Program
# 5                     NaN   6    active  Little House Recreational Activities
# 6                     NaN   7    active      Rosener House Adult Day Services
# 7                     NaN   8    active        Meals on Wheels - South County
# 8                     NaN   9    active                      Fair Oaks Branch
# 9                     NaN  10    active                          Main Library
# 10                    NaN  11    active                       Schaberg Branch
# ...

# %%
df.dtypes
# Out:
# id                           int64
# location_id                  int64
# program_id                 float64
# accepted_payments           object
# alternate_name              object
# application_process         object
# audience                    object
# description                 object
# eligibility                 object
# email                       object
# fees                        object
# funding_sources             object
# interpretation_services     object
# keywords                    object
# languages                   object
# name                        object
# required_documents          object
# service_areas               object
# status                      object
# wait_time                   object
# website                     object
# taxonomy_ids                object
# dtype: object

# %%
pd.read_excel("/content/drive/MyDrive/LUSID Excel - Setting up your market data.xlsx")
# Out:
#     Unnamed: 0  Unnamed: 1  Unnamed: 2  \
# 0          NaN         NaN         NaN
# 1          NaN         NaN         NaN
# 2          NaN         NaN         NaN
# 3          NaN         NaN         NaN
# 4          NaN         NaN         NaN
# 5          NaN         NaN         NaN
# 6          NaN         NaN         NaN
# 7          NaN         NaN         NaN
# 8          NaN         NaN         NaN
# 9          NaN         NaN         NaN
# 10         NaN         NaN         NaN
# 11         NaN         NaN         NaN
# 12         NaN         NaN         NaN
# 13         NaN         NaN         NaN
# 14         NaN         NaN         NaN
# 15         NaN         NaN         NaN
# 16         NaN         NaN         NaN
# 17         NaN         NaN         NaN
# 18         NaN         NaN         NaN
# 19         NaN         NaN         NaN
# 20         NaN         NaN         NaN
# 21         NaN         NaN         NaN
# 22         NaN         NaN         NaN
# ...

# %%
df1  = pd.read_excel("/content/drive/MyDrive/LUSID Excel - Setting up your market data.xlsx")

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
df1.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9'],
#       dtype='object')

# %%
df1.dtypes
# Out:
# Unnamed: 0    float64
# Unnamed: 1    float64
# Unnamed: 2    float64
# Unnamed: 3     object
# Unnamed: 4     object
# Unnamed: 5     object
# Unnamed: 6    float64
# Unnamed: 7     object
# Unnamed: 8     object
# Unnamed: 9     object
# dtype: object

# %%
df1[['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2']]
# Out:
#     Unnamed: 0  Unnamed: 1  Unnamed: 2
# 0          NaN         NaN         NaN
# 1          NaN         NaN         NaN
# 2          NaN         NaN         NaN
# 3          NaN         NaN         NaN
# 4          NaN         NaN         NaN
# 5          NaN         NaN         NaN
# 6          NaN         NaN         NaN
# 7          NaN         NaN         NaN
# 8          NaN         NaN         NaN
# 9          NaN         NaN         NaN
# 10         NaN         NaN         NaN
# 11         NaN         NaN         NaN
# 12         NaN         NaN         NaN
# 13         NaN         NaN         NaN
# 14         NaN         NaN         NaN
# 15         NaN         NaN         NaN
# 16         NaN         NaN         NaN
# 17         NaN         NaN         NaN
# 18         NaN         NaN         NaN
# 19         NaN         NaN         NaN
# 20         NaN         NaN         NaN
# 21         NaN         NaN         NaN
# 22         NaN         NaN         NaN
# ...

# %%
pip install lxml

# %%
import lxml
import pandas as pd
url_data = pd.read_html("https://www.basketball-reference.com/leagues/NBA_2022.html")

# %%
type(url_data)
# Out:
# list

# %%
df2 = url_data[0]

# %%
df2
# Out:
#      Eastern Conference   W   L   W/L%    GB   PS/G   PA/G   SRS
# 0           Miami Heat*  53  29  0.646     —  110.0  105.6  4.23
# 1       Boston Celtics*  51  31  0.622   2.0  111.8  104.5  7.02
# 2      Milwaukee Bucks*  51  31  0.622   2.0  115.5  112.1  3.22
# 3   Philadelphia 76ers*  51  31  0.622   2.0  109.9  107.3  2.57
# 4      Toronto Raptors*  48  34  0.585   5.0  109.4  107.1  2.38
# 5        Chicago Bulls*  46  36  0.561   7.0  111.6  112.0 -0.38
# 6        Brooklyn Nets*  44  38  0.537   9.0  112.9  112.1  0.82
# 7   Cleveland Cavaliers  44  38  0.537   9.0  107.8  105.7  2.04
# 8        Atlanta Hawks*  43  39  0.524  10.0  113.9  112.4  1.55
# 9     Charlotte Hornets  43  39  0.524  10.0  115.3  114.9  0.53
# 10      New York Knicks  37  45  0.451  16.0  106.5  106.6 -0.01
# 11   Washington Wizards  35  47  0.427  18.0  108.6  112.0 -3.23
# 12       Indiana Pacers  25  57  0.305  28.0  111.5  114.9 -3.26
# ...

# %%
df2.head()
# Out:
#     Eastern Conference   W   L   W/L%   GB   PS/G   PA/G   SRS
# 0          Miami Heat*  53  29  0.646    —  110.0  105.6  4.23
# 1      Boston Celtics*  51  31  0.622  2.0  111.8  104.5  7.02
# 2     Milwaukee Bucks*  51  31  0.622  2.0  115.5  112.1  3.22
# 3  Philadelphia 76ers*  51  31  0.622  2.0  109.9  107.3  2.57
# 4     Toronto Raptors*  48  34  0.585  5.0  109.4  107.1  2.38

# %%
df2.tail()
# Out:
#     Eastern Conference   W   L   W/L%    GB   PS/G   PA/G   SRS
# 10     New York Knicks  37  45  0.451  16.0  106.5  106.6 -0.01
# 11  Washington Wizards  35  47  0.427  18.0  108.6  112.0 -3.23
# 12      Indiana Pacers  25  57  0.305  28.0  111.5  114.9 -3.26
# 13     Detroit Pistons  23  59  0.280  30.0  104.8  112.5 -7.36
# 14       Orlando Magic  22  60  0.268  31.0  104.2  112.2 -7.67

# %%
df2.columns
# Out:
# Index(['Eastern Conference', 'W', 'L', 'W/L%', 'GB', 'PS/G', 'PA/G', 'SRS'], dtype='object')

# %%
df2.dtypes
# Out:
# Eastern Conference     object
# W                       int64
# L                       int64
# W/L%                  float64
# GB                     object
# PS/G                  float64
# PA/G                  float64
# SRS                   float64
# dtype: object

# %%
df2[[ 'W', 'L', 'W/L%']]
# Out:
#      W   L   W/L%
# 0   53  29  0.646
# 1   51  31  0.622
# 2   51  31  0.622
# 3   51  31  0.622
# 4   48  34  0.585
# 5   46  36  0.561
# 6   44  38  0.537
# 7   44  38  0.537
# 8   43  39  0.524
# 9   43  39  0.524
# 10  37  45  0.451
# 11  35  47  0.427
# 12  25  57  0.305
# 13  23  59  0.280
# 14  22  60  0.268

# %%
df2.to_csv("Playoff_teams.csv")
